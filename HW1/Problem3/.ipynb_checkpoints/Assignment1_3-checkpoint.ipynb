# %%
# Assignment 1_3 Character-Level Language Modeling

# -*- coding: utf-8 -*-
import os
import re
import sys
import math
import random

# %%
"""Get all files name under path

Args:
    path: folder path to retrieve files' name.
    ratio: propotion of training data. Default value is 1 (100%).
    suffix: type of files
    shuffle: a boolean value. TRUE: shuffle list; False: order list.

Returns:
    filesName[:train]: a list of all files end with ".txt" for training set. For example:

    ["dir/a.txt", "dir/b.txt"].

    filesName[train:]: a list of all files end with ".txt" for held-out set. For example:

    ["dir/a.txt", "dir/b.txt"].
"""
def getFilesName( path, ratio = 1, suffix = ".txt", shuffle = False ):
    print( "Retrieving files name from folder %s..." % ( path ) )
    filesName = []
    files = os.listdir( path )
    for file in files:
        if os.path.splitext( file )[1] == suffix:
            name = '/'.join( [path, file] )
            filesName.append( name )
    if shuffle:
        random.shuffle( filesName )
    else:
        filesName.sort()
    total = len( filesName )
    train = int( total * ratio )
    return filesName[:train], filesName[train:]

# %%
"""Preprocess data

1. Remove blank lines from each file.
2. Replace newline characters with spaces.
3. Remove duplicate spaces.

Args:
    fileName: fileName indicating which file that need to be processed.
    encoding: the encoding of inputing file. Default value is "Latin-1".

Returns:
    content: a string containing processed content from file. For example:
    
    "A cat"
"""
def preprocess( fileName, encoding = "Latin-1" ):
    print( "Preprocessing file %s..." % ( fileName ) )
    content = ""
    with open( fileName, 'r', encoding = encoding ) as f:
        line = f.readline()
        while line:
            line = re.sub( "\s", " ", line )
            line = re.sub( "_", "", line )
            line = re.sub( "[^\w\s]", "", line )
            content += line
            line = f.readline()
        content = re.sub( "\s+", " ", content ).strip()
    return content

"""Preprocess data

4. Replace characters in training set that appear ≤ 5 times as “UNK”.

Note: The function will figure out all characters which are need to be replaced by "UNK"
      and they will be replaced when building n-gram character-level language model.

Args:
    content: string to be processed.

Returns:
    repc: a string of characters that need to be replaced with "UNK". For example:
    
    "[abc]"
"""
def unk( content ):
    d = {}
    for c in content:
        if c not in d:
            d[c] = 0
        d[c] += 1
    repc = []
    for ( k, v ) in d.items():
        if v <= 5:
            repc.append( k )
    repc = '[' + "".join( repc ) + ']'
    return repc

# %%
# Problem 3.1
"""Generate n-gram dictionary.

Generate n-gram dictionary based on fed string and n.

Note: replace characters in content with "?" which represents "UNK" in character-level.

Args:
    content: content used to calculate ngrams.
    repc: characters that need to be replaced with "UNK".
    n: n-gram.
    d: dictionary correspond to n-gram.

Returns:
    None.
"""
def ngrams( content, repc, n, d ):
    if len( repc ) > 2:
        content = re.sub( repc, "?", content )
    length = len( content )
    for i in range( 0, length - n + 1 ):
        k = content[i:i + n]
        if k not in d:
            d[k] = 0
        d[k] += 1

"""Build language model

Preprocess files and across all files in the directory (counted together), report the 
unigram, bigram, and trigram character counts.

Args:
    trainFiles: a list contains all training files' name.
    encoding: train data files' encoding.

Returns:
    lm: a dictionary of language model when savePath equals empty string. Its structure is:
    
    {"unigram": {"c": unigram, "t": total unigram characters},
     "bigram" : {"c": bigram,  "t": total bigram  characters},
     "trigram": {"c": trigram, "t": total trigram characters}}.
"""
def LM( trainFiles, encoding = "Latin-1"  ):
    print( "Building language modeling..." )
    lm = {"unigram": {"c": {}, "t": 0},
          "bigram" : {"c": {}, "t": 0},
          "trigram": {"c": {}, "t": 0}}
    ngram = ["unigram", "bigram", "trigram"]
    
    # preprocess data and find UNK
    print( "Counting for finding UNK.")
    content = ""
    for fileName in trainFiles:
        content += preprocess( fileName, encoding )
    repc = unk( content )
    
    # Calculate unigram, bigram, and trigram
    print( "Calculating n-grams..." )
    for fileName in trainFiles:
        content = preprocess( fileName, encoding )
        ngrams( content, repc, 1, lm["unigram"]["c"] )
        ngrams( content, repc, 2, lm["bigram" ]["c"] )
        ngrams( content, repc, 3, lm["trigram"]["c"] )
    for name in ngram:
        lm[name]["t"] = sum( lm[name]["c"].values() )
    return lm

"""Main function of problem 3.1

Across all files in the directory (counted together), report the unigram, bigram, and trigram
character counts and save them in seperate files.

Args:
    trainDataPath: train data path.
    encoding: train data files' encoding
    savePath: path to save language model.
    ratio: the proportion of the real training set comparing to whole training set

Returns:
    None
"""
def buildLM( trainDataPath = "./gutenberg", encoding = "Latin-1", savePath = "./lm", ratio = 1 ):
    ngram = ["unigram", "bigram", "trigram"]
    trainFiles, heldOutFiles = getFilesName( trainDataPath )
    lm = LM( trainFiles, encoding = encoding )
    for name in ngram:
        with open( savePath + "/" + name, "w" ) as f:
            f.write( str( lm[name]["t"] ) + "\n" )
            for ( k, v ) in lm[name]["c"].items():
                f.write( k + " " + str( v ) + "\n" )

# %%
# Problem 3.2
"""Linear Interplotation Smoothing

P(w_{n}|w_{n-2}w_{n-1}) = lambda3 * P(w_{n}|w_{n-2}w_{n-1}) +
                          lambda2 * P(w_{n}|w_{n-1}) +
                          lambda1 * P(w_{n})
    where lambda1 + lambda2 + lambda3 = 1.

Args:
    lm: a dictionary contains language model. Its structure is:
    
    {"unigram": {"c": unigram, "t": total unigram characters},
     "bigram" : {"c": bigram,  "t": total bigram  characters},
     "trigram": {"c": trigram, "t": total trigram characters}}.

    lambdas: a dictionary of lambda for interplotation or addLambda. Its structure is:
    
    {1: lambdaForUnigram, 2: lambdaForBigram, 3: lambdaForTrigram}.

    s: string wating for calculating unigram, bigram, and trigram.

Returns:
    p: a double number represents the final probability of P(w_{n}|w_{n-2}w_{n-1}).
"""
def interplotation( lm, lambdas, s ):
    s1 = s[2:]
    s2 = s[1:]
    s3 = s[0:]
    if s1 not in lm["unigram"]["c"]:
        p1 = lm["unigram"]["c"]["?"] / lm["unigram"]["t"]
    else:
        p1 = lm["unigram"]["c"][s1] / lm["unigram"]["t"]
    if s2 not in lm["bigram"]["c"] or s1 not in lm["unigram"]["c"]:
        p2 = 0
    else:
        p2 = lm["bigram" ]["c"][s2] / lm["unigram" ]["c"][s1]
    if s3 not in lm["trigram"]["c"] or s2 not in lm["bigram"]["c"]:
        p3 = 0
    else:
        p3 = lm["trigram"]["c"][s3] / lm["bigram"]["c"][s2]
    p = lambdas[1] * p1 + lambdas[2] * p2 + lambdas[3] * p3
    return p

"""Calculate perplexity

PP(W) = P(w_1w_2 ... w_n)^(-1/n)
      = 2^{-1 / n * sum_{i=1:n}(log2(LM(w_i|w_{i-2}w_{i-1})))}

Note: Since here is no <SOS> and <EOS> in language model, n would be the length of
      the content - 2.

Args:
    content: string content.
    lm: a dictionary contains language model. Its structure is:
    
    {"unigram": {"c": unigram, "t": total unigram characters},
     "bigram" : {"c": bigram,  "t": total bigram  characters},
     "trigram": {"c": trigram, "t": total trigram characters}}.

    **kwargs:
        func: smoothing function name on calculating P(w_i|w_{i-2}w_{i-1}), including
              func = "Interplotation" and func = "AddLambda".
        
        lambdas: a dictionary of lambda for interplotation or addLambda. Its structure is:
    
        {1: lambdaForUnigram, 2:lambdaForBigram, 3:lambdaForTrigram}
        
        When using addLambda function, only need to feed one specific lambda.
    
Returns:
    ppw: a double number represents the perplexity of the content.

Raise:
    KeyError: an error when trying to find smoothing function.
"""
def perplexity( content, lm, **kwargs ):
    length = len( content )
    log2p = 0
    if( length <= 2 ):
        raise Exception( "Too short content." )
    if "func" in kwargs:
        if kwargs["func"] == "Interplotation":
            for i in range( length - 1 ):
                p = interplotation( lm, kwargs["lambdas"], content[i:i + 3] )
                log2p += math.log2( p )
        elif kwargs["func"] == "AddLambda":
            for i in range( length - 1 ):
                p = addLambda( lm, kwargs["lambdas"], content[i:i + 3] )
                log2p += math.log2( p )
        else:
            raise Exception( "Cannot find the smoothing function." )
    else:
        raise Exception( "No smoothing function." )
    log2p *= -1 / ( length - 2 )
    ppw = 2 ** log2p
    return ppw

"""Grid search

Using grid search and held-out data set find the best lambdas for
linear interplotation smoothing.

Args:
    lambdas: a generator of lambdas which generate a dictionary of lambdas
             for unigram, bigram, trigram each time. For example:
    
    {1:0.1, 2:0.1, 3:0.8}
    
    lm: a dictionary of language model. Its structure is:
    
    {"unigram": {"c": unigram, "t": total unigram characters},
     "bigram" : {"c": bigram,  "t": total bigram  characters},
     "trigram": {"c": trigram, "t": total trigram characters}}.
    
    heldOutFiles: files name belongs to held-out data set.

Returns:
    lambdas: the best lambdas combination.
"""
def gridSearch( lambdas, lm, heldOutFiles ):
    print( "Applying grid search..." )
    minAvg = float( "inf" )
    for lambd in lambdas:
        avg = 0
        for name in heldOutFiles:
            content = preprocess( name )
            avg += perplexity( content, lm, func = "Interplotation", lambdas = lambd )
        if( avg < minAvg ):
            minAvg = avg
            bestLambda = lambd
    return bestLambda

"""Main function for Problem 3.2

Calculate the perplexity for each le in the test set using linear interpolation smoothing
method.

Note: Here I sperate the training data and held-out data by seperating number of files rather
      than seperating all content after concatenating all together and then dividing them.
      
      There are two reasons to divide data in this way
      1. It is hard and cumbersome to measure 80% of the content just on name list.
      2. If loading all content into memory at the same time, it is too time consuming and
         wastes time without obviously improvment on final language model.

Args:
    trainDataPath: train data path.
    encoding: train data files' encoding
    savePath: path to save language model. If it equals to empty string, the function returns
              language model.
    testDataPath: test data path.
    ratio: the proportion of the real training set comparing to whole training set.

Returns:
    None.
"""
def interplotationPPW( trainDataPath = "./gutenberg", encoding = "Latin-1", savePath = "./3_2",
                       testDataPath = "./test_data", ratio = 0.8 ):
    # Get new language model
    trainFiles, heldOutFiles = getFilesName( trainDataPath, ratio = ratio, shuffle = True )
    lm = LM( trainFiles, encoding = encoding )

    # Choose lambdas by grid search and perplexity
    lambdas = ( {1: x / 10, 2: y / 10, 3: ( 10 - x - y ) / 10}
                   for x in range( 1, 10, 1 ) for y in range( 1, 10 - x, 1 ) )
    lambdas = gridSearch( lambdas, lm, heldOutFiles )

    # File-PPW pair dictionary
    dfp = {}
    filesName, _ = getFilesName( testDataPath, suffix = "" )
    for fileName in filesName:
        content = preprocess( fileName )
        ppw = perplexity( content, lm, func = "Interplotation", lambdas = lambdas )
        dfp[fileName] = ppw
    fps = sorted( dfp.items(), key = lambda x: x[1], reverse = True )
    with open( savePath + "/" + "filesPerplexity.txt", 'w' ) as f:
        for fp in fps:
            f.write( fp[0].split( '/' )[-1] + ", " + str( fp[1] ) + "\n" )

# %%
# Problem 3.3
"""Load language model

Load language model from folder "lm" and save them into dictionary "lm".

Args:
    loadPath: language model load path.
    encoding: language model files' encoding

Returns:
    lm: a dictionary of language model. Its structure is:
    
    {"unigram": {"c": unigram, "t": total unigram characters},
     "bigram" : {"c": bigram,  "t": total bigram  characters},
     "trigram": {"c": trigram, "t": total trigram characters}}.
"""
def loadLM( loadPath = "./lm", encoding = "utf-8" ):
    lm = {}
    ngram = ["unigram", "bigram", "trigram"]
    n = 0
    # load unigram, bigram, and trigram
    for name in ngram:
        n += 1
        with open( loadPath + "/" + name, "r", encoding = encoding ) as f:
            ngram = {}
            total = 0
            line = f.readline()
            while line:
                kv = line.split( ' ' )
                if len( kv ) > 1:
                    kv[0] = line[:n]
                    kv[1] = line[n + 1:]
                    ngram[kv[0]] = int( kv[1] )
                else:
                    total = int( kv[0] )
                line = f.readline()
            lm[name] = {"c": ngram, "t": total}
    return lm

"""Add lambda smoothing

P(w_{n}|w_{n-1}w_{n-2}) = ( c(w_{n-1}w_{n-2}, w_{n}) + lambda ) /
                            ( c(w_{n-1}w_{n-1}) + lambda * V )

Args:
    lm: a dictionary of language model. Its structure is:
    
    {"unigram": {"c": unigram, "t": total unigram characters},
     "bigram" : {"c": bigram,  "t": total bigram  characters},
     "trigram": {"c": trigram, "t": total trigram characters}}.
    
    lambdas: a generator of lambdas which generate a dictionary of lambdas
             for unigram, bigram, trigram each time. For example:
    
    {1:0.1, 2:0.1, 3:0.8}
    
    s: string wating for calculating unigram, bigram, and trigram.

Returns:
    p: a double number represents the final probability of P(w_{n}|w_{n-2}w_{n-1}).
"""
def addLambda( lm, lambdas, s ):
    if s not in lm["trigram"]["c"]:
        cnt1 = 0
    else:
        cnt1 = lm["trigram"]["c"][s]
    if s[:2] not in lm["bigram"]["c"]:
        cnt2 = 0
    else:
        cnt2 = lm["bigram"]["c"][s[:2]]
    p = ( cnt1 + lambdas[3] ) / ( cnt2 + len( lm["bigram"]["c"] ) * lambdas[3] )
    return p

"""Main function for problem 3.3

Calculate the perplexity for each le in the test set using linear interpolation smoothing
method.

Args:
    trainDataPath: train data path.
    encoding: train data files' encoding
    savePath: path to save language model. If it equals to empty string, the function returns
              language model.
    testDataPath: test data path.
    ratio: the proportion of the real training set comparing to whole training set.

Returns:
    None.
"""
def addLambdaPPW( lmPath = "./lm", encoding = "Latin-1", savePath = "./3_3",
                  testDataPath = "./test_data" ):
    # Get new language model
    lm = loadLM( lmPath, encoding )
    lambdas = {3: 0.1}
    # File-PPW pair dictionary
    dfp = {}
    filesName, _ = getFilesName( testDataPath, suffix = "" )
    for fileName in filesName:
        content = preprocess( fileName )
        ppw = perplexity( content, lm, func = "AddLambda", lambdas = lambdas )
        dfp[fileName] = ppw
    fps = sorted( dfp.items(), key = lambda x: x[1], reverse = True )
    with open( savePath + "/" + "filesPerplexity.txt", 'w' ) as f:
        for fp in fps:
            f.write( fp[0].split( '/' )[-1] + ", " + str( fp[1] ) + "\n" )

# %%
def assignment1_3():
    # problem 3.1
    print( "Running problem 3.1" )
    buildLM( trainDataPath = "./gutenberg", encoding = "Latin-1", savePath = "./lm",
             ratio = 1 )
    # problem 3.2
    print( "Running problem 3.2" )
    interplotationPPW( trainDataPath = "./gutenberg", encoding = "Latin-1",
                       savePath = "./3_2", testDataPath = "./test_data", ratio = 0.8 )
    # problem 3.3
    print( "Running problem 3.3" )
    addLambdaPPW( lmPath = "./lm", encoding = "Latin-1", savePath = "./3_3",
                  testDataPath = "./test_data" )

# %%
assignment1_3()
# Out:
# Running problem 3.1
# Retrieving files name from folder ./gutenberg...
# Building language modeling...
# Counting for finding UNK.
# Preprocessing file ./gutenberg/austen-emma.txt...
# Preprocessing file ./gutenberg/austen-persuasion.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bible-kjv.txt...
# Preprocessing file ./gutenberg/blake-poems.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/burgess-busterbrown.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-ball.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/chesterton-thursday.txt...
# Preprocessing file ./gutenberg/edgeworth-parents.txt...
# Preprocessing file ./gutenberg/melville-moby_dick.txt...
# Preprocessing file ./gutenberg/milton-paradise.txt...
# Preprocessing file ./gutenberg/shakespeare-caesar.txt...
# Preprocessing file ./gutenberg/shakespeare-hamlet.txt...
# Preprocessing file ./gutenberg/shakespeare-macbeth.txt...
# Preprocessing file ./gutenberg/whitman-leaves.txt...
# Calculating n-grams...
# Preprocessing file ./gutenberg/austen-emma.txt...
# Preprocessing file ./gutenberg/austen-persuasion.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bible-kjv.txt...
# Preprocessing file ./gutenberg/blake-poems.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/burgess-busterbrown.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-ball.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/chesterton-thursday.txt...
# Preprocessing file ./gutenberg/edgeworth-parents.txt...
# Preprocessing file ./gutenberg/melville-moby_dick.txt...
# Preprocessing file ./gutenberg/milton-paradise.txt...
# Preprocessing file ./gutenberg/shakespeare-caesar.txt...
# Preprocessing file ./gutenberg/shakespeare-hamlet.txt...
# Preprocessing file ./gutenberg/shakespeare-macbeth.txt...
# Preprocessing file ./gutenberg/whitman-leaves.txt...
# Running problem 3.2
# Retrieving files name from folder ./gutenberg...
# Building language modeling...
# Counting for finding UNK.
# Preprocessing file ./gutenberg/austen-emma.txt...
# Preprocessing file ./gutenberg/bible-kjv.txt...
# Preprocessing file ./gutenberg/whitman-leaves.txt...
# Preprocessing file ./gutenberg/shakespeare-macbeth.txt...
# Preprocessing file ./gutenberg/milton-paradise.txt...
# Preprocessing file ./gutenberg/shakespeare-hamlet.txt...
# Preprocessing file ./gutenberg/chesterton-thursday.txt...
# Preprocessing file ./gutenberg/austen-persuasion.txt...
# Preprocessing file ./gutenberg/blake-poems.txt...
# Preprocessing file ./gutenberg/edgeworth-parents.txt...
# Preprocessing file ./gutenberg/shakespeare-caesar.txt...
# Preprocessing file ./gutenberg/melville-moby_dick.txt...
# Preprocessing file ./gutenberg/burgess-busterbrown.txt...
# Preprocessing file ./gutenberg/chesterton-ball.txt...
# Calculating n-grams...
# Preprocessing file ./gutenberg/austen-emma.txt...
# Preprocessing file ./gutenberg/bible-kjv.txt...
# Preprocessing file ./gutenberg/whitman-leaves.txt...
# Preprocessing file ./gutenberg/shakespeare-macbeth.txt...
# Preprocessing file ./gutenberg/milton-paradise.txt...
# Preprocessing file ./gutenberg/shakespeare-hamlet.txt...
# Preprocessing file ./gutenberg/chesterton-thursday.txt...
# Preprocessing file ./gutenberg/austen-persuasion.txt...
# Preprocessing file ./gutenberg/blake-poems.txt...
# Preprocessing file ./gutenberg/edgeworth-parents.txt...
# Preprocessing file ./gutenberg/shakespeare-caesar.txt...
# Preprocessing file ./gutenberg/melville-moby_dick.txt...
# Preprocessing file ./gutenberg/burgess-busterbrown.txt...
# Preprocessing file ./gutenberg/chesterton-ball.txt...
# Applying grid search...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Preprocessing file ./gutenberg/chesterton-brown.txt...
# Preprocessing file ./gutenberg/austen-sense.txt...
# Preprocessing file ./gutenberg/bryant-stories.txt...
# Preprocessing file ./gutenberg/carroll-alice.txt...
# Retrieving files name from folder ./test_data...
# Preprocessing file ./test_data/0000...
# Preprocessing file ./test_data/0010...
# Preprocessing file ./test_data/0028...
# Preprocessing file ./test_data/0031...
# Preprocessing file ./test_data/0051...
# Preprocessing file ./test_data/0053...
# Preprocessing file ./test_data/0064...
# Preprocessing file ./test_data/0079...
# Preprocessing file ./test_data/0096...
# Preprocessing file ./test_data/0139...
# Preprocessing file ./test_data/0144...
# Preprocessing file ./test_data/0146...
# Preprocessing file ./test_data/0153...
# Preprocessing file ./test_data/0155...
# Preprocessing file ./test_data/0168...
# Preprocessing file ./test_data/0191...
# Preprocessing file ./test_data/0192...
# Preprocessing file ./test_data/0220...
# Preprocessing file ./test_data/0234...
# Preprocessing file ./test_data/0244...
# Preprocessing file ./test_data/0249...
# Preprocessing file ./test_data/0254...
# Preprocessing file ./test_data/0255...
# Preprocessing file ./test_data/0263...
# Preprocessing file ./test_data/0267...
# Preprocessing file ./test_data/0288...
# Preprocessing file ./test_data/0317...
# Preprocessing file ./test_data/0319...
# Preprocessing file ./test_data/0322...
# Preprocessing file ./test_data/0342...
# Preprocessing file ./test_data/0347...
# Preprocessing file ./test_data/0350...
# Preprocessing file ./test_data/0351...
# Preprocessing file ./test_data/0355...
# Preprocessing file ./test_data/0368...
# Preprocessing file ./test_data/0371...
# Preprocessing file ./test_data/0382...
# Preprocessing file ./test_data/0392...
# Preprocessing file ./test_data/0404...
# Preprocessing file ./test_data/0407...
# Preprocessing file ./test_data/0427...
# Preprocessing file ./test_data/0435...
# Preprocessing file ./test_data/0440...
# Preprocessing file ./test_data/0443...
# Preprocessing file ./test_data/0459...
# Preprocessing file ./test_data/0471...
# Preprocessing file ./test_data/0494...
# Preprocessing file ./test_data/0497...
# Preprocessing file ./test_data/0499...
# Preprocessing file ./test_data/0500...
# Preprocessing file ./test_data/0510...
# Preprocessing file ./test_data/0525...
# Preprocessing file ./test_data/0535...
# Preprocessing file ./test_data/0538...
# Preprocessing file ./test_data/0556...
# Preprocessing file ./test_data/0562...
# Preprocessing file ./test_data/0563...
# Preprocessing file ./test_data/0581...
# Preprocessing file ./test_data/0597...
# Preprocessing file ./test_data/0599...
# Preprocessing file ./test_data/0608...
# Preprocessing file ./test_data/0611...
# Preprocessing file ./test_data/0631...
# Preprocessing file ./test_data/0648...
# Preprocessing file ./test_data/0666...
# Preprocessing file ./test_data/0680...
# Preprocessing file ./test_data/0693...
# Preprocessing file ./test_data/0706...
# Preprocessing file ./test_data/0707...
# Preprocessing file ./test_data/0712...
# Preprocessing file ./test_data/0724...
# Preprocessing file ./test_data/0747...
# Preprocessing file ./test_data/0766...
# Preprocessing file ./test_data/0771...
# Preprocessing file ./test_data/0774...
# Preprocessing file ./test_data/0782...
# Preprocessing file ./test_data/0801...
# Preprocessing file ./test_data/0805...
# Preprocessing file ./test_data/0807...
# Preprocessing file ./test_data/0809...
# Preprocessing file ./test_data/0820...
# Preprocessing file ./test_data/0822...
# Preprocessing file ./test_data/0832...
# Preprocessing file ./test_data/0836...
# Preprocessing file ./test_data/0839...
# Preprocessing file ./test_data/0863...
# Preprocessing file ./test_data/0864...
# Preprocessing file ./test_data/0866...
# Preprocessing file ./test_data/0894...
# Preprocessing file ./test_data/0907...
# Preprocessing file ./test_data/0908...
# Preprocessing file ./test_data/0925...
# Preprocessing file ./test_data/0946...
# Preprocessing file ./test_data/0961...
# Preprocessing file ./test_data/0982...
# Preprocessing file ./test_data/0984...
# Preprocessing file ./test_data/1010...
# Preprocessing file ./test_data/1015...
# Preprocessing file ./test_data/1018...
# Preprocessing file ./test_data/1019...
# Preprocessing file ./test_data/1021...
# Preprocessing file ./test_data/1023...
# Preprocessing file ./test_data/1039...
# Preprocessing file ./test_data/1050...
# Preprocessing file ./test_data/1059...
# Preprocessing file ./test_data/1071...
# Preprocessing file ./test_data/1077...
# Preprocessing file ./test_data/1083...
# Preprocessing file ./test_data/1086...
# Preprocessing file ./test_data/1089...
# Preprocessing file ./test_data/1093...
# Preprocessing file ./test_data/1118...
# Preprocessing file ./test_data/1168...
# Preprocessing file ./test_data/1186...
# Preprocessing file ./test_data/1196...
# Preprocessing file ./test_data/1209...
# Preprocessing file ./test_data/1211...
# Preprocessing file ./test_data/1212...
# Preprocessing file ./test_data/1215...
# Preprocessing file ./test_data/1231...
# Preprocessing file ./test_data/1249...
# Preprocessing file ./test_data/1266...
# Preprocessing file ./test_data/1276...
# Preprocessing file ./test_data/1277...
# Preprocessing file ./test_data/1336...
# Preprocessing file ./test_data/1342...
# Preprocessing file ./test_data/1346...
# Preprocessing file ./test_data/1353...
# Preprocessing file ./test_data/1362...
# Preprocessing file ./test_data/1370...
# Preprocessing file ./test_data/1377...
# Preprocessing file ./test_data/1380...
# Preprocessing file ./test_data/1386...
# Preprocessing file ./test_data/1390...
# Preprocessing file ./test_data/1405...
# Preprocessing file ./test_data/1406...
# Preprocessing file ./test_data/1417...
# Preprocessing file ./test_data/1437...
# Preprocessing file ./test_data/1448...
# Preprocessing file ./test_data/1454...
# Preprocessing file ./test_data/1481...
# Preprocessing file ./test_data/1499...
# Preprocessing file ./test_data/1504...
# Preprocessing file ./test_data/1505...
# Preprocessing file ./test_data/1515...
# Preprocessing file ./test_data/1518...
# Preprocessing file ./test_data/1555...
# Preprocessing file ./test_data/1557...
# Preprocessing file ./test_data/1564...
# Preprocessing file ./test_data/1566...
# Preprocessing file ./test_data/1573...
# Preprocessing file ./test_data/1575...
# Preprocessing file ./test_data/1605...
# Preprocessing file ./test_data/1606...
# Preprocessing file ./test_data/1623...
# Preprocessing file ./test_data/1624...
# Preprocessing file ./test_data/1626...
# Preprocessing file ./test_data/1639...
# Preprocessing file ./test_data/1644...
# Preprocessing file ./test_data/1693...
# Preprocessing file ./test_data/1704...
# Preprocessing file ./test_data/1721...
# Preprocessing file ./test_data/1733...
# Preprocessing file ./test_data/1744...
# Preprocessing file ./test_data/1747...
# Preprocessing file ./test_data/1751...
# Preprocessing file ./test_data/1753...
# Preprocessing file ./test_data/1758...
# Preprocessing file ./test_data/1793...
# Preprocessing file ./test_data/1795...
# Preprocessing file ./test_data/1809...
# Preprocessing file ./test_data/1810...
# Preprocessing file ./test_data/1821...
# Preprocessing file ./test_data/1826...
# Preprocessing file ./test_data/1830...
# Preprocessing file ./test_data/1843...
# Preprocessing file ./test_data/1847...
# Preprocessing file ./test_data/1856...
# Preprocessing file ./test_data/1868...
# Preprocessing file ./test_data/1869...
# Preprocessing file ./test_data/1877...
# Preprocessing file ./test_data/1893...
# Preprocessing file ./test_data/1895...
# Preprocessing file ./test_data/1898...
# Preprocessing file ./test_data/1902...
# Preprocessing file ./test_data/1912...
# Preprocessing file ./test_data/1915...
# Preprocessing file ./test_data/1927...
# Preprocessing file ./test_data/1931...
# Preprocessing file ./test_data/1944...
# Preprocessing file ./test_data/1949...
# Preprocessing file ./test_data/1958...
# Preprocessing file ./test_data/1967...
# Preprocessing file ./test_data/1970...
# Preprocessing file ./test_data/1978...
# Preprocessing file ./test_data/1994...
# Preprocessing file ./test_data/2006...
# Preprocessing file ./test_data/2013...
# Preprocessing file ./test_data/2057...
# Preprocessing file ./test_data/2065...
# Preprocessing file ./test_data/2074...
# Preprocessing file ./test_data/2093...
# Preprocessing file ./test_data/2097...
# Preprocessing file ./test_data/2149...
# Preprocessing file ./test_data/2151...
# Preprocessing file ./test_data/2153...
# Preprocessing file ./test_data/2154...
# Preprocessing file ./test_data/2168...
# Preprocessing file ./test_data/2171...
# Preprocessing file ./test_data/2173...
# Preprocessing file ./test_data/2174...
# Preprocessing file ./test_data/2176...
# Preprocessing file ./test_data/2177...
# Preprocessing file ./test_data/2181...
# Preprocessing file ./test_data/2183...
# Preprocessing file ./test_data/2184...
# Preprocessing file ./test_data/2189...
# Preprocessing file ./test_data/2198...
# Preprocessing file ./test_data/2230...
# Preprocessing file ./test_data/2251...
# Preprocessing file ./test_data/2254...
# Preprocessing file ./test_data/2276...
# Preprocessing file ./test_data/2289...
# Preprocessing file ./test_data/2291...
# Preprocessing file ./test_data/2301...
# Preprocessing file ./test_data/2303...
# Preprocessing file ./test_data/2304...
# Preprocessing file ./test_data/2314...
# Preprocessing file ./test_data/2315...
# Preprocessing file ./test_data/2316...
# Preprocessing file ./test_data/2351...
# Preprocessing file ./test_data/2352...
# Preprocessing file ./test_data/2375...
# Preprocessing file ./test_data/2379...
# Preprocessing file ./test_data/2384...
# Preprocessing file ./test_data/2389...
# Preprocessing file ./test_data/2399...
# Preprocessing file ./test_data/2400...
# Preprocessing file ./test_data/2408...
# Preprocessing file ./test_data/2413...
# Preprocessing file ./test_data/2424...
# Preprocessing file ./test_data/2439...
# Preprocessing file ./test_data/2457...
# Preprocessing file ./test_data/2493...
# Preprocessing file ./test_data/2507...
# Preprocessing file ./test_data/2508...
# Preprocessing file ./test_data/2521...
# Preprocessing file ./test_data/2534...
# Preprocessing file ./test_data/2564...
# Preprocessing file ./test_data/2586...
# Preprocessing file ./test_data/2595...
# Preprocessing file ./test_data/2623...
# Preprocessing file ./test_data/2643...
# Preprocessing file ./test_data/2647...
# Preprocessing file ./test_data/2656...
# Preprocessing file ./test_data/2677...
# Preprocessing file ./test_data/2704...
# Preprocessing file ./test_data/2705...
# Preprocessing file ./test_data/2712...
# Preprocessing file ./test_data/2715...
# Preprocessing file ./test_data/2723...
# Preprocessing file ./test_data/2725...
# Preprocessing file ./test_data/2734...
# Preprocessing file ./test_data/2743...
# Preprocessing file ./test_data/2745...
# Preprocessing file ./test_data/2750...
# Preprocessing file ./test_data/2762...
# Preprocessing file ./test_data/2769...
# Preprocessing file ./test_data/2781...
# Preprocessing file ./test_data/2796...
# Preprocessing file ./test_data/2800...
# Preprocessing file ./test_data/2802...
# Preprocessing file ./test_data/2814...
# Preprocessing file ./test_data/2819...
# Preprocessing file ./test_data/2833...
# Preprocessing file ./test_data/2850...
# Preprocessing file ./test_data/2865...
# Preprocessing file ./test_data/2876...
# Preprocessing file ./test_data/2884...
# Preprocessing file ./test_data/2886...
# Preprocessing file ./test_data/2894...
# Preprocessing file ./test_data/2897...
# Preprocessing file ./test_data/2900...
# Preprocessing file ./test_data/2901...
# Preprocessing file ./test_data/2939...
# Preprocessing file ./test_data/2944...
# Preprocessing file ./test_data/2952...
# Preprocessing file ./test_data/2954...
# Preprocessing file ./test_data/2957...
# Preprocessing file ./test_data/2969...
# Preprocessing file ./test_data/2986...
# Preprocessing file ./test_data/3014...
# Preprocessing file ./test_data/3016...
# Preprocessing file ./test_data/3018...
# Preprocessing file ./test_data/3046...
# Preprocessing file ./test_data/3051...
# Preprocessing file ./test_data/3066...
# Preprocessing file ./test_data/3067...
# Preprocessing file ./test_data/3068...
# Preprocessing file ./test_data/3071...
# Preprocessing file ./test_data/3076...
# Preprocessing file ./test_data/3082...
# Preprocessing file ./test_data/3105...
# Preprocessing file ./test_data/3109...
# Preprocessing file ./test_data/3110...
# Preprocessing file ./test_data/3112...
# Preprocessing file ./test_data/3135...
# Preprocessing file ./test_data/3160...
# Preprocessing file ./test_data/3161...
# Preprocessing file ./test_data/3177...
# Preprocessing file ./test_data/3182...
# Preprocessing file ./test_data/3188...
# Preprocessing file ./test_data/3203...
# Preprocessing file ./test_data/3215...
# Preprocessing file ./test_data/3227...
# Preprocessing file ./test_data/3231...
# Preprocessing file ./test_data/3236...
# Preprocessing file ./test_data/3247...
# Preprocessing file ./test_data/3265...
# Preprocessing file ./test_data/3273...
# Preprocessing file ./test_data/3275...
# Preprocessing file ./test_data/3277...
# Preprocessing file ./test_data/3286...
# Preprocessing file ./test_data/3291...
# Preprocessing file ./test_data/3329...
# Preprocessing file ./test_data/3341...
# Preprocessing file ./test_data/3348...
# Preprocessing file ./test_data/3349...
# Preprocessing file ./test_data/3366...
# Preprocessing file ./test_data/3385...
# Preprocessing file ./test_data/3395...
# Preprocessing file ./test_data/3402...
# Preprocessing file ./test_data/3403...
# Preprocessing file ./test_data/3413...
# Preprocessing file ./test_data/3418...
# Preprocessing file ./test_data/3430...
# Preprocessing file ./test_data/3441...
# Preprocessing file ./test_data/3442...
# Preprocessing file ./test_data/3444...
# Preprocessing file ./test_data/3475...
# Preprocessing file ./test_data/3492...
# Preprocessing file ./test_data/3493...
# Preprocessing file ./test_data/3517...
# Preprocessing file ./test_data/3539...
# Preprocessing file ./test_data/3541...
# Preprocessing file ./test_data/3554...
# Preprocessing file ./test_data/3560...
# Preprocessing file ./test_data/3564...
# Preprocessing file ./test_data/3575...
# Preprocessing file ./test_data/3582...
# Preprocessing file ./test_data/3623...
# Preprocessing file ./test_data/3660...
# Preprocessing file ./test_data/3668...
# Preprocessing file ./test_data/3673...
# Preprocessing file ./test_data/3687...
# Preprocessing file ./test_data/3689...
# Preprocessing file ./test_data/3709...
# Preprocessing file ./test_data/3727...
# Preprocessing file ./test_data/3734...
# Preprocessing file ./test_data/3765...
# Preprocessing file ./test_data/3773...
# Preprocessing file ./test_data/3784...
# Preprocessing file ./test_data/3794...
# Preprocessing file ./test_data/3804...
# Preprocessing file ./test_data/3812...
# Preprocessing file ./test_data/3813...
# Preprocessing file ./test_data/3820...
# Preprocessing file ./test_data/3839...
# Preprocessing file ./test_data/3841...
# Preprocessing file ./test_data/3855...
# Preprocessing file ./test_data/3864...
# Preprocessing file ./test_data/3866...
# Preprocessing file ./test_data/3872...
# Preprocessing file ./test_data/3894...
# Preprocessing file ./test_data/3895...
# Preprocessing file ./test_data/3896...
# Preprocessing file ./test_data/3907...
# Preprocessing file ./test_data/3921...
# Preprocessing file ./test_data/3959...
# Preprocessing file ./test_data/3975...
# Preprocessing file ./test_data/3977...
# Preprocessing file ./test_data/3983...
# Preprocessing file ./test_data/3987...
# Preprocessing file ./test_data/3995...
# Preprocessing file ./test_data/4005...
# Preprocessing file ./test_data/4006...
# Preprocessing file ./test_data/4008...
# Preprocessing file ./test_data/4009...
# Preprocessing file ./test_data/4015...
# Preprocessing file ./test_data/4041...
# Preprocessing file ./test_data/4045...
# Preprocessing file ./test_data/4049...
# Preprocessing file ./test_data/4061...
# Preprocessing file ./test_data/4073...
# Preprocessing file ./test_data/4079...
# Preprocessing file ./test_data/4095...
# Preprocessing file ./test_data/4102...
# Preprocessing file ./test_data/4111...
# Preprocessing file ./test_data/4125...
# Preprocessing file ./test_data/4128...
# Preprocessing file ./test_data/4133...
# Preprocessing file ./test_data/4138...
# Preprocessing file ./test_data/4145...
# Preprocessing file ./test_data/4151...
# Preprocessing file ./test_data/4165...
# Preprocessing file ./test_data/4169...
# Preprocessing file ./test_data/4182...
# Preprocessing file ./test_data/4186...
# Preprocessing file ./test_data/4199...
# Preprocessing file ./test_data/4208...
# Preprocessing file ./test_data/4216...
# Preprocessing file ./test_data/4217...
# Preprocessing file ./test_data/4223...
# Preprocessing file ./test_data/4243...
# Preprocessing file ./test_data/4254...
# Preprocessing file ./test_data/4262...
# Preprocessing file ./test_data/4264...
# Preprocessing file ./test_data/4271...
# Preprocessing file ./test_data/4288...
# Preprocessing file ./test_data/4291...
# Preprocessing file ./test_data/4298...
# Preprocessing file ./test_data/4310...
# Preprocessing file ./test_data/4318...
# Preprocessing file ./test_data/4330...
# Preprocessing file ./test_data/4332...
# Preprocessing file ./test_data/4335...
# Preprocessing file ./test_data/4338...
# Preprocessing file ./test_data/4355...
# Preprocessing file ./test_data/4361...
# Preprocessing file ./test_data/4369...
# Preprocessing file ./test_data/4383...
# Preprocessing file ./test_data/4398...
# Preprocessing file ./test_data/4401...
# Preprocessing file ./test_data/4417...
# Preprocessing file ./test_data/4423...
# Preprocessing file ./test_data/4432...
# Preprocessing file ./test_data/4434...
# Preprocessing file ./test_data/4447...
# Preprocessing file ./test_data/4469...
# Preprocessing file ./test_data/4476...
# Preprocessing file ./test_data/4484...
# Preprocessing file ./test_data/4489...
# Preprocessing file ./test_data/4490...
# Preprocessing file ./test_data/4492...
# Preprocessing file ./test_data/4493...
# Preprocessing file ./test_data/4505...
# Preprocessing file ./test_data/4516...
# Preprocessing file ./test_data/4523...
# Preprocessing file ./test_data/4538...
# Preprocessing file ./test_data/4545...
# Preprocessing file ./test_data/4572...
# Preprocessing file ./test_data/4586...
# Preprocessing file ./test_data/4598...
# Preprocessing file ./test_data/4599...
# Preprocessing file ./test_data/4603...
# Preprocessing file ./test_data/4628...
# Preprocessing file ./test_data/4636...
# Preprocessing file ./test_data/4639...
# Preprocessing file ./test_data/4650...
# Preprocessing file ./test_data/4658...
# Preprocessing file ./test_data/4672...
# Preprocessing file ./test_data/4691...
# Preprocessing file ./test_data/4693...
# Preprocessing file ./test_data/4704...
# Preprocessing file ./test_data/4724...
# Preprocessing file ./test_data/4725...
# Preprocessing file ./test_data/4735...
# Preprocessing file ./test_data/4743...
# Preprocessing file ./test_data/4762...
# Preprocessing file ./test_data/4777...
# Preprocessing file ./test_data/4782...
# Preprocessing file ./test_data/4787...
# Preprocessing file ./test_data/4791...
# Preprocessing file ./test_data/4805...
# Preprocessing file ./test_data/4816...
# Preprocessing file ./test_data/4826...
# Preprocessing file ./test_data/4828...
# Preprocessing file ./test_data/4835...
# Preprocessing file ./test_data/4838...
# Preprocessing file ./test_data/4852...
# Preprocessing file ./test_data/4869...
# Preprocessing file ./test_data/4875...
# Preprocessing file ./test_data/4876...
# Preprocessing file ./test_data/4877...
# Preprocessing file ./test_data/4890...
# Preprocessing file ./test_data/4914...
# Preprocessing file ./test_data/4919...
# Preprocessing file ./test_data/4934...
# Preprocessing file ./test_data/4945...
# Preprocessing file ./test_data/4967...
# Preprocessing file ./test_data/4983...
# Preprocessing file ./test_data/4989...
# Preprocessing file ./test_data/5003...
# Preprocessing file ./test_data/5025...
# Preprocessing file ./test_data/5030...
# Preprocessing file ./test_data/5049...
# Preprocessing file ./test_data/5062...
# Preprocessing file ./test_data/5094...
# Preprocessing file ./test_data/5096...
# Preprocessing file ./test_data/5097...
# Preprocessing file ./test_data/5099...
# Preprocessing file ./test_data/5126...
# Preprocessing file ./test_data/5147...
# Preprocessing file ./test_data/5168...
# Preprocessing file ./test_data/5182...
# Preprocessing file ./test_data/5192...
# Preprocessing file ./test_data/5220...
# Preprocessing file ./test_data/5222...
# Preprocessing file ./test_data/5247...
# Preprocessing file ./test_data/5263...
# Preprocessing file ./test_data/5264...
# Preprocessing file ./test_data/5267...
# Preprocessing file ./test_data/5289...
# Preprocessing file ./test_data/5290...
# Preprocessing file ./test_data/5300...
# Preprocessing file ./test_data/5342...
# Preprocessing file ./test_data/5345...
# Preprocessing file ./test_data/5348...
# Preprocessing file ./test_data/5371...
# Preprocessing file ./test_data/5378...
# Preprocessing file ./test_data/5391...
# Preprocessing file ./test_data/5433...
# Preprocessing file ./test_data/5438...
# Preprocessing file ./test_data/5447...
# Preprocessing file ./test_data/5448...
# Preprocessing file ./test_data/5450...
# Preprocessing file ./test_data/5459...
# Preprocessing file ./test_data/5460...
# Preprocessing file ./test_data/5485...
# Preprocessing file ./test_data/5487...
# Preprocessing file ./test_data/5506...
# Preprocessing file ./test_data/5508...
# Preprocessing file ./test_data/5514...
# Preprocessing file ./test_data/5537...
# Preprocessing file ./test_data/5546...
# Preprocessing file ./test_data/5557...
# Preprocessing file ./test_data/5562...
# Preprocessing file ./test_data/5564...
# Preprocessing file ./test_data/5565...
# Preprocessing file ./test_data/5569...
# Preprocessing file ./test_data/5570...
# Preprocessing file ./test_data/5578...
# Preprocessing file ./test_data/5579...
# Preprocessing file ./test_data/5580...
# Preprocessing file ./test_data/5625...
# Preprocessing file ./test_data/5627...
# Preprocessing file ./test_data/5634...
# Preprocessing file ./test_data/5639...
# Preprocessing file ./test_data/5653...
# Preprocessing file ./test_data/5654...
# Preprocessing file ./test_data/5675...
# Preprocessing file ./test_data/5689...
# Preprocessing file ./test_data/5704...
# Preprocessing file ./test_data/5706...
# Preprocessing file ./test_data/5716...
# Preprocessing file ./test_data/5723...
# Preprocessing file ./test_data/5725...
# Preprocessing file ./test_data/5735...
# Preprocessing file ./test_data/5740...
# Preprocessing file ./test_data/5747...
# Preprocessing file ./test_data/5750...
# Preprocessing file ./test_data/5753...
# Preprocessing file ./test_data/5773...
# Preprocessing file ./test_data/5782...
# Preprocessing file ./test_data/5813...
# Preprocessing file ./test_data/5822...
# Preprocessing file ./test_data/5824...
# Preprocessing file ./test_data/5828...
# Preprocessing file ./test_data/5833...
# Preprocessing file ./test_data/5840...
# Preprocessing file ./test_data/5847...
# Preprocessing file ./test_data/5860...
# Preprocessing file ./test_data/5877...
# Preprocessing file ./test_data/5886...
# Preprocessing file ./test_data/5901...
# Preprocessing file ./test_data/5906...
# Preprocessing file ./test_data/5912...
# Preprocessing file ./test_data/5922...
# Preprocessing file ./test_data/5940...
# Preprocessing file ./test_data/5944...
# Preprocessing file ./test_data/5946...
# Preprocessing file ./test_data/5955...
# Preprocessing file ./test_data/5956...
# Preprocessing file ./test_data/5961...
# Preprocessing file ./test_data/5970...
# Preprocessing file ./test_data/5972...
# Preprocessing file ./test_data/5981...
# Preprocessing file ./test_data/5987...
# Preprocessing file ./test_data/5993...
# Preprocessing file ./test_data/6011...
# Preprocessing file ./test_data/6018...
# Preprocessing file ./test_data/6019...
# Preprocessing file ./test_data/6024...
# Preprocessing file ./test_data/6031...
# Preprocessing file ./test_data/6052...
# Preprocessing file ./test_data/6055...
# Preprocessing file ./test_data/6060...
# Preprocessing file ./test_data/6070...
# Preprocessing file ./test_data/6081...
# Preprocessing file ./test_data/6093...
# Preprocessing file ./test_data/6094...
# Preprocessing file ./test_data/6106...
# Preprocessing file ./test_data/6111...
# Preprocessing file ./test_data/6117...
# Preprocessing file ./test_data/6118...
# Preprocessing file ./test_data/6139...
# Preprocessing file ./test_data/6140...
# Preprocessing file ./test_data/6157...
# Preprocessing file ./test_data/6160...
# Preprocessing file ./test_data/6172...
# Preprocessing file ./test_data/6191...
# Preprocessing file ./test_data/6193...
# Preprocessing file ./test_data/6197...
# Preprocessing file ./test_data/6214...
# Preprocessing file ./test_data/6243...
# Preprocessing file ./test_data/6252...
# Preprocessing file ./test_data/6260...
# Preprocessing file ./test_data/6264...
# Preprocessing file ./test_data/6275...
# Preprocessing file ./test_data/6292...
# Preprocessing file ./test_data/6297...
# Preprocessing file ./test_data/6298...
# Preprocessing file ./test_data/6341...
# Preprocessing file ./test_data/6348...
# Preprocessing file ./test_data/6352...
# Preprocessing file ./test_data/6358...
# Preprocessing file ./test_data/6363...
# Preprocessing file ./test_data/6370...
# Preprocessing file ./test_data/6374...
# Preprocessing file ./test_data/6378...
# Preprocessing file ./test_data/6419...
# Preprocessing file ./test_data/6446...
# Preprocessing file ./test_data/6452...
# Preprocessing file ./test_data/6482...
# Preprocessing file ./test_data/6507...
# Preprocessing file ./test_data/6541...
# Preprocessing file ./test_data/6564...
# Preprocessing file ./test_data/6565...
# Preprocessing file ./test_data/6566...
# Preprocessing file ./test_data/6570...
# Preprocessing file ./test_data/6571...
# Preprocessing file ./test_data/6575...
# Preprocessing file ./test_data/6609...
# Preprocessing file ./test_data/6610...
# Preprocessing file ./test_data/6611...
# Preprocessing file ./test_data/6612...
# Preprocessing file ./test_data/6616...
# Preprocessing file ./test_data/6641...
# Preprocessing file ./test_data/6644...
# Preprocessing file ./test_data/6656...
# Preprocessing file ./test_data/6665...
# Preprocessing file ./test_data/6667...
# Preprocessing file ./test_data/6676...
# Preprocessing file ./test_data/6684...
# Preprocessing file ./test_data/6701...
# Preprocessing file ./test_data/6702...
# Preprocessing file ./test_data/6703...
# Preprocessing file ./test_data/6705...
# Preprocessing file ./test_data/6724...
# Preprocessing file ./test_data/6729...
# Preprocessing file ./test_data/6734...
# Preprocessing file ./test_data/6737...
# Preprocessing file ./test_data/6738...
# Preprocessing file ./test_data/6741...
# Preprocessing file ./test_data/6743...
# Preprocessing file ./test_data/6755...
# Preprocessing file ./test_data/6756...
# Preprocessing file ./test_data/6769...
# Preprocessing file ./test_data/6772...
# Preprocessing file ./test_data/6788...
# Preprocessing file ./test_data/6792...
# Preprocessing file ./test_data/6793...
# Preprocessing file ./test_data/6799...
# Preprocessing file ./test_data/6820...
# Preprocessing file ./test_data/6822...
# Preprocessing file ./test_data/6832...
# Preprocessing file ./test_data/6833...
# Preprocessing file ./test_data/6838...
# Preprocessing file ./test_data/6839...
# Preprocessing file ./test_data/6860...
# Preprocessing file ./test_data/6883...
# Preprocessing file ./test_data/6887...
# Preprocessing file ./test_data/6892...
# Preprocessing file ./test_data/6896...
# Preprocessing file ./test_data/6933...
# Preprocessing file ./test_data/6945...
# Preprocessing file ./test_data/6951...
# Preprocessing file ./test_data/6974...
# Preprocessing file ./test_data/6979...
# Preprocessing file ./test_data/6984...
# Preprocessing file ./test_data/7010...
# Preprocessing file ./test_data/7014...
# Preprocessing file ./test_data/7015...
# Preprocessing file ./test_data/7017...
# Preprocessing file ./test_data/7042...
# Preprocessing file ./test_data/7047...
# Preprocessing file ./test_data/7052...
# Preprocessing file ./test_data/7056...
# Preprocessing file ./test_data/7061...
# Preprocessing file ./test_data/7062...
# Preprocessing file ./test_data/7078...
# Preprocessing file ./test_data/7108...
# Preprocessing file ./test_data/7110...
# Preprocessing file ./test_data/7128...
# Preprocessing file ./test_data/7131...
# Preprocessing file ./test_data/7135...
# Preprocessing file ./test_data/7136...
# Preprocessing file ./test_data/7138...
# Preprocessing file ./test_data/7144...
# Preprocessing file ./test_data/7170...
# Preprocessing file ./test_data/7213...
# Preprocessing file ./test_data/7215...
# Preprocessing file ./test_data/7216...
# Preprocessing file ./test_data/7245...
# Preprocessing file ./test_data/7248...
# Preprocessing file ./test_data/7254...
# Preprocessing file ./test_data/7256...
# Preprocessing file ./test_data/7257...
# Preprocessing file ./test_data/7269...
# Preprocessing file ./test_data/7322...
# Preprocessing file ./test_data/7323...
# Preprocessing file ./test_data/7349...
# Preprocessing file ./test_data/7357...
# Preprocessing file ./test_data/7358...
# Preprocessing file ./test_data/7381...
# Preprocessing file ./test_data/7382...
# Preprocessing file ./test_data/7383...
# Preprocessing file ./test_data/7384...
# Preprocessing file ./test_data/7387...
# Preprocessing file ./test_data/7392...
# Preprocessing file ./test_data/7393...
# Preprocessing file ./test_data/7404...
# Preprocessing file ./test_data/7408...
# Preprocessing file ./test_data/7413...
# Preprocessing file ./test_data/7416...
# Preprocessing file ./test_data/7419...
# Preprocessing file ./test_data/7424...
# Preprocessing file ./test_data/7438...
# Preprocessing file ./test_data/7444...
# Preprocessing file ./test_data/7448...
# Preprocessing file ./test_data/7453...
# Preprocessing file ./test_data/7462...
# Preprocessing file ./test_data/7464...
# Preprocessing file ./test_data/7481...
# Preprocessing file ./test_data/7484...
# Preprocessing file ./test_data/7486...
# Preprocessing file ./test_data/7501...
# Preprocessing file ./test_data/7502...
# Preprocessing file ./test_data/7503...
# Preprocessing file ./test_data/7512...
# Preprocessing file ./test_data/7524...
# Preprocessing file ./test_data/7534...
# Preprocessing file ./test_data/7540...
# Preprocessing file ./test_data/7549...
# Preprocessing file ./test_data/7555...
# Preprocessing file ./test_data/7564...
# Preprocessing file ./test_data/7569...
# Preprocessing file ./test_data/7585...
# Preprocessing file ./test_data/7586...
# Preprocessing file ./test_data/7588...
# Preprocessing file ./test_data/7600...
# Preprocessing file ./test_data/7603...
# Preprocessing file ./test_data/7611...
# Preprocessing file ./test_data/7613...
# Preprocessing file ./test_data/7670...
# Preprocessing file ./test_data/7693...
# Preprocessing file ./test_data/7699...
# Preprocessing file ./test_data/7718...
# Preprocessing file ./test_data/7737...
# Preprocessing file ./test_data/7757...
# Preprocessing file ./test_data/7785...
# Preprocessing file ./test_data/7793...
# Preprocessing file ./test_data/7810...
# Preprocessing file ./test_data/7821...
# Preprocessing file ./test_data/7848...
# Preprocessing file ./test_data/7872...
# Preprocessing file ./test_data/7873...
# Preprocessing file ./test_data/7879...
# Preprocessing file ./test_data/7880...
# Preprocessing file ./test_data/7889...
# Preprocessing file ./test_data/7921...
# Preprocessing file ./test_data/7929...
# Preprocessing file ./test_data/7932...
# Preprocessing file ./test_data/7938...
# Preprocessing file ./test_data/7940...
# Preprocessing file ./test_data/7950...
# Preprocessing file ./test_data/7955...
# Preprocessing file ./test_data/7968...
# Preprocessing file ./test_data/7979...
# Preprocessing file ./test_data/7980...
# Preprocessing file ./test_data/7999...
# Preprocessing file ./test_data/8005...
# Preprocessing file ./test_data/8021...
# Preprocessing file ./test_data/8051...
# Preprocessing file ./test_data/8072...
# Preprocessing file ./test_data/8075...
# Preprocessing file ./test_data/8084...
# Preprocessing file ./test_data/8091...
# Preprocessing file ./test_data/8110...
# Preprocessing file ./test_data/8128...
# Preprocessing file ./test_data/8136...
# Preprocessing file ./test_data/8141...
# Preprocessing file ./test_data/8142...
# Preprocessing file ./test_data/8154...
# Preprocessing file ./test_data/8156...
# Preprocessing file ./test_data/8157...
# Preprocessing file ./test_data/8166...
# Preprocessing file ./test_data/8181...
# Preprocessing file ./test_data/8184...
# Preprocessing file ./test_data/8187...
# Preprocessing file ./test_data/8198...
# Preprocessing file ./test_data/8202...
# Preprocessing file ./test_data/8213...
# Preprocessing file ./test_data/8227...
# Preprocessing file ./test_data/8250...
# Preprocessing file ./test_data/8251...
# Preprocessing file ./test_data/8255...
# Preprocessing file ./test_data/8275...
# Preprocessing file ./test_data/8277...
# Preprocessing file ./test_data/8288...
# Preprocessing file ./test_data/8301...
# Preprocessing file ./test_data/8332...
# Preprocessing file ./test_data/8335...
# Preprocessing file ./test_data/8339...
# Preprocessing file ./test_data/8341...
# Preprocessing file ./test_data/8344...
# Preprocessing file ./test_data/8352...
# Preprocessing file ./test_data/8360...
# Preprocessing file ./test_data/8375...
# Preprocessing file ./test_data/8380...
# Preprocessing file ./test_data/8388...
# Preprocessing file ./test_data/8415...
# Preprocessing file ./test_data/8430...
# Preprocessing file ./test_data/8431...
# Preprocessing file ./test_data/8437...
# Preprocessing file ./test_data/8439...
# Preprocessing file ./test_data/8445...
# Preprocessing file ./test_data/8447...
# Preprocessing file ./test_data/8450...
# Preprocessing file ./test_data/8452...
# Preprocessing file ./test_data/8461...
# Preprocessing file ./test_data/8473...
# Preprocessing file ./test_data/8509...
# Preprocessing file ./test_data/8513...
# Preprocessing file ./test_data/8514...
# Preprocessing file ./test_data/8517...
# Preprocessing file ./test_data/8521...
# Preprocessing file ./test_data/8544...
# Preprocessing file ./test_data/8548...
# Preprocessing file ./test_data/8552...
# Preprocessing file ./test_data/8562...
# Preprocessing file ./test_data/8565...
# Preprocessing file ./test_data/8569...
# Preprocessing file ./test_data/8570...
# Preprocessing file ./test_data/8588...
# Preprocessing file ./test_data/8601...
# Preprocessing file ./test_data/8607...
# Preprocessing file ./test_data/8613...
# Preprocessing file ./test_data/8617...
# Preprocessing file ./test_data/8619...
# Preprocessing file ./test_data/8655...
# Preprocessing file ./test_data/8665...
# Preprocessing file ./test_data/8676...
# Preprocessing file ./test_data/8696...
# Preprocessing file ./test_data/8703...
# Preprocessing file ./test_data/8729...
# Preprocessing file ./test_data/8731...
# Preprocessing file ./test_data/8733...
# Preprocessing file ./test_data/8740...
# Preprocessing file ./test_data/8746...
# Preprocessing file ./test_data/8764...
# Preprocessing file ./test_data/8766...
# Preprocessing file ./test_data/8768...
# Preprocessing file ./test_data/8770...
# Preprocessing file ./test_data/8772...
# Preprocessing file ./test_data/8777...
# Preprocessing file ./test_data/8782...
# Preprocessing file ./test_data/8786...
# Preprocessing file ./test_data/8830...
# Preprocessing file ./test_data/8838...
# Preprocessing file ./test_data/8846...
# Preprocessing file ./test_data/8847...
# Preprocessing file ./test_data/8853...
# Preprocessing file ./test_data/8854...
# Preprocessing file ./test_data/8856...
# Preprocessing file ./test_data/8867...
# Preprocessing file ./test_data/8869...
# Preprocessing file ./test_data/8894...
# Preprocessing file ./test_data/8895...
# Preprocessing file ./test_data/8901...
# Preprocessing file ./test_data/8906...
# Preprocessing file ./test_data/8915...
# Preprocessing file ./test_data/8916...
# Preprocessing file ./test_data/8919...
# Preprocessing file ./test_data/8935...
# Preprocessing file ./test_data/8948...
# Preprocessing file ./test_data/8953...
# Preprocessing file ./test_data/8959...
# Preprocessing file ./test_data/8963...
# Preprocessing file ./test_data/8977...
# Preprocessing file ./test_data/8978...
# Preprocessing file ./test_data/9003...
# Preprocessing file ./test_data/9005...
# Preprocessing file ./test_data/9032...
# Preprocessing file ./test_data/9042...
# Preprocessing file ./test_data/9072...
# Preprocessing file ./test_data/9100...
# Preprocessing file ./test_data/9105...
# Preprocessing file ./test_data/9114...
# Preprocessing file ./test_data/9119...
# Preprocessing file ./test_data/9122...
# Preprocessing file ./test_data/9125...
# Preprocessing file ./test_data/9126...
# Preprocessing file ./test_data/9143...
# Preprocessing file ./test_data/9147...
# Preprocessing file ./test_data/9171...
# Preprocessing file ./test_data/9194...
# Preprocessing file ./test_data/9208...
# Preprocessing file ./test_data/9229...
# Preprocessing file ./test_data/9231...
# Preprocessing file ./test_data/9235...
# Preprocessing file ./test_data/9259...
# Preprocessing file ./test_data/9260...
# Preprocessing file ./test_data/9315...
# Preprocessing file ./test_data/9323...
# Preprocessing file ./test_data/9365...
# Preprocessing file ./test_data/9367...
# Preprocessing file ./test_data/9369...
# Preprocessing file ./test_data/9379...
# Preprocessing file ./test_data/9400...
# Preprocessing file ./test_data/9420...
# Preprocessing file ./test_data/9424...
# Preprocessing file ./test_data/9445...
# Preprocessing file ./test_data/9448...
# Preprocessing file ./test_data/9459...
# Preprocessing file ./test_data/9460...
# Preprocessing file ./test_data/9482...
# ...
# Preprocessing file ./test_data/6018...
# Preprocessing file ./test_data/6019...
# Preprocessing file ./test_data/6024...
# Preprocessing file ./test_data/6031...
# Preprocessing file ./test_data/6052...
# Preprocessing file ./test_data/6055...
# Preprocessing file ./test_data/6060...
# Preprocessing file ./test_data/6070...
# Preprocessing file ./test_data/6081...
# Preprocessing file ./test_data/6093...
# Preprocessing file ./test_data/6094...
# Preprocessing file ./test_data/6106...
# Preprocessing file ./test_data/6111...
# Preprocessing file ./test_data/6117...
# Preprocessing file ./test_data/6118...
# Preprocessing file ./test_data/6139...
# Preprocessing file ./test_data/6140...
# Preprocessing file ./test_data/6157...
# Preprocessing file ./test_data/6160...
# Preprocessing file ./test_data/6172...
# Preprocessing file ./test_data/6191...
# Preprocessing file ./test_data/6193...
# Preprocessing file ./test_data/6197...
# Preprocessing file ./test_data/6214...
# Preprocessing file ./test_data/6243...
# Preprocessing file ./test_data/6252...
# Preprocessing file ./test_data/6260...
# Preprocessing file ./test_data/6264...
# Preprocessing file ./test_data/6275...
# Preprocessing file ./test_data/6292...
# Preprocessing file ./test_data/6297...
# Preprocessing file ./test_data/6298...
# Preprocessing file ./test_data/6341...
# Preprocessing file ./test_data/6348...
# Preprocessing file ./test_data/6352...
# Preprocessing file ./test_data/6358...
# Preprocessing file ./test_data/6363...
# Preprocessing file ./test_data/6370...
# Preprocessing file ./test_data/6374...
# Preprocessing file ./test_data/6378...
# Preprocessing file ./test_data/6419...
# Preprocessing file ./test_data/6446...
# Preprocessing file ./test_data/6452...
# Preprocessing file ./test_data/6482...
# Preprocessing file ./test_data/6507...
# Preprocessing file ./test_data/6541...
# Preprocessing file ./test_data/6564...
# Preprocessing file ./test_data/6565...
# Preprocessing file ./test_data/6566...
# Preprocessing file ./test_data/6570...
# Preprocessing file ./test_data/6571...
# Preprocessing file ./test_data/6575...
# Preprocessing file ./test_data/6609...
# Preprocessing file ./test_data/6610...
# Preprocessing file ./test_data/6611...
# Preprocessing file ./test_data/6612...
# Preprocessing file ./test_data/6616...
# Preprocessing file ./test_data/6641...
# Preprocessing file ./test_data/6644...
# Preprocessing file ./test_data/6656...
# Preprocessing file ./test_data/6665...
# Preprocessing file ./test_data/6667...
# Preprocessing file ./test_data/6676...
# Preprocessing file ./test_data/6684...
# Preprocessing file ./test_data/6701...
# Preprocessing file ./test_data/6702...
# Preprocessing file ./test_data/6703...
# Preprocessing file ./test_data/6705...
# Preprocessing file ./test_data/6724...
# Preprocessing file ./test_data/6729...
# Preprocessing file ./test_data/6734...
# Preprocessing file ./test_data/6737...
# Preprocessing file ./test_data/6738...
# Preprocessing file ./test_data/6741...
# Preprocessing file ./test_data/6743...
# Preprocessing file ./test_data/6755...
# Preprocessing file ./test_data/6756...
# Preprocessing file ./test_data/6769...
# Preprocessing file ./test_data/6772...
# Preprocessing file ./test_data/6788...
# Preprocessing file ./test_data/6792...
# Preprocessing file ./test_data/6793...
# Preprocessing file ./test_data/6799...
# Preprocessing file ./test_data/6820...
# Preprocessing file ./test_data/6822...
# Preprocessing file ./test_data/6832...
# Preprocessing file ./test_data/6833...
# Preprocessing file ./test_data/6838...
# Preprocessing file ./test_data/6839...
# Preprocessing file ./test_data/6860...
# Preprocessing file ./test_data/6883...
# Preprocessing file ./test_data/6887...
# Preprocessing file ./test_data/6892...
# Preprocessing file ./test_data/6896...
# Preprocessing file ./test_data/6933...
# Preprocessing file ./test_data/6945...
# Preprocessing file ./test_data/6951...
# Preprocessing file ./test_data/6974...
# Preprocessing file ./test_data/6979...
# Preprocessing file ./test_data/6984...
# Preprocessing file ./test_data/7010...
# Preprocessing file ./test_data/7014...
# Preprocessing file ./test_data/7015...
# Preprocessing file ./test_data/7017...
# Preprocessing file ./test_data/7042...
# Preprocessing file ./test_data/7047...
# Preprocessing file ./test_data/7052...
# Preprocessing file ./test_data/7056...
# Preprocessing file ./test_data/7061...
# Preprocessing file ./test_data/7062...
# Preprocessing file ./test_data/7078...
# Preprocessing file ./test_data/7108...
# Preprocessing file ./test_data/7110...
# Preprocessing file ./test_data/7128...
# Preprocessing file ./test_data/7131...
# Preprocessing file ./test_data/7135...
# Preprocessing file ./test_data/7136...
# Preprocessing file ./test_data/7138...
# Preprocessing file ./test_data/7144...
# Preprocessing file ./test_data/7170...
# Preprocessing file ./test_data/7213...
# Preprocessing file ./test_data/7215...
# Preprocessing file ./test_data/7216...
# Preprocessing file ./test_data/7245...
# Preprocessing file ./test_data/7248...
# Preprocessing file ./test_data/7254...
# Preprocessing file ./test_data/7256...
# Preprocessing file ./test_data/7257...
# Preprocessing file ./test_data/7269...
# Preprocessing file ./test_data/7322...
# Preprocessing file ./test_data/7323...
# Preprocessing file ./test_data/7349...
# Preprocessing file ./test_data/7357...
# Preprocessing file ./test_data/7358...
# Preprocessing file ./test_data/7381...
# Preprocessing file ./test_data/7382...
# Preprocessing file ./test_data/7383...
# Preprocessing file ./test_data/7384...
# Preprocessing file ./test_data/7387...
# Preprocessing file ./test_data/7392...
# Preprocessing file ./test_data/7393...
# Preprocessing file ./test_data/7404...
# Preprocessing file ./test_data/7408...
# Preprocessing file ./test_data/7413...
# Preprocessing file ./test_data/7416...
# Preprocessing file ./test_data/7419...
# Preprocessing file ./test_data/7424...
# Preprocessing file ./test_data/7438...
# Preprocessing file ./test_data/7444...
# Preprocessing file ./test_data/7448...
# Preprocessing file ./test_data/7453...
# Preprocessing file ./test_data/7462...
# Preprocessing file ./test_data/7464...
# Preprocessing file ./test_data/7481...
# Preprocessing file ./test_data/7484...
# Preprocessing file ./test_data/7486...
# Preprocessing file ./test_data/7501...
# Preprocessing file ./test_data/7502...
# Preprocessing file ./test_data/7503...
# Preprocessing file ./test_data/7512...
# Preprocessing file ./test_data/7524...
# Preprocessing file ./test_data/7534...
# Preprocessing file ./test_data/7540...
# Preprocessing file ./test_data/7549...
# Preprocessing file ./test_data/7555...
# Preprocessing file ./test_data/7564...
# Preprocessing file ./test_data/7569...
# Preprocessing file ./test_data/7585...
# Preprocessing file ./test_data/7586...
# Preprocessing file ./test_data/7588...
# Preprocessing file ./test_data/7600...
# Preprocessing file ./test_data/7603...
# Preprocessing file ./test_data/7611...
# Preprocessing file ./test_data/7613...
# Preprocessing file ./test_data/7670...
# Preprocessing file ./test_data/7693...
# Preprocessing file ./test_data/7699...
# Preprocessing file ./test_data/7718...
# Preprocessing file ./test_data/7737...
# Preprocessing file ./test_data/7757...
# Preprocessing file ./test_data/7785...
# Preprocessing file ./test_data/7793...
# Preprocessing file ./test_data/7810...
# Preprocessing file ./test_data/7821...
# Preprocessing file ./test_data/7848...
# Preprocessing file ./test_data/7872...
# Preprocessing file ./test_data/7873...
# Preprocessing file ./test_data/7879...
# Preprocessing file ./test_data/7880...
# Preprocessing file ./test_data/7889...
# Preprocessing file ./test_data/7921...
# Preprocessing file ./test_data/7929...
# Preprocessing file ./test_data/7932...
# Preprocessing file ./test_data/7938...
# Preprocessing file ./test_data/7940...
# Preprocessing file ./test_data/7950...
# Preprocessing file ./test_data/7955...
# Preprocessing file ./test_data/7968...
# Preprocessing file ./test_data/7979...
# Preprocessing file ./test_data/7980...
# Preprocessing file ./test_data/7999...
# Preprocessing file ./test_data/8005...
# Preprocessing file ./test_data/8021...
# Preprocessing file ./test_data/8051...
# Preprocessing file ./test_data/8072...
# Preprocessing file ./test_data/8075...
# Preprocessing file ./test_data/8084...
# Preprocessing file ./test_data/8091...
# Preprocessing file ./test_data/8110...
# Preprocessing file ./test_data/8128...
# Preprocessing file ./test_data/8136...
# Preprocessing file ./test_data/8141...
# Preprocessing file ./test_data/8142...
# Preprocessing file ./test_data/8154...
# Preprocessing file ./test_data/8156...
# Preprocessing file ./test_data/8157...
# Preprocessing file ./test_data/8166...
# Preprocessing file ./test_data/8181...
# Preprocessing file ./test_data/8184...
# Preprocessing file ./test_data/8187...
# Preprocessing file ./test_data/8198...
# Preprocessing file ./test_data/8202...
# Preprocessing file ./test_data/8213...
# Preprocessing file ./test_data/8227...
# Preprocessing file ./test_data/8250...
# Preprocessing file ./test_data/8251...
# Preprocessing file ./test_data/8255...
# Preprocessing file ./test_data/8275...
# Preprocessing file ./test_data/8277...
# Preprocessing file ./test_data/8288...
# Preprocessing file ./test_data/8301...
# Preprocessing file ./test_data/8332...
# Preprocessing file ./test_data/8335...
# Preprocessing file ./test_data/8339...
# Preprocessing file ./test_data/8341...
# Preprocessing file ./test_data/8344...
# Preprocessing file ./test_data/8352...
# Preprocessing file ./test_data/8360...
# Preprocessing file ./test_data/8375...
# Preprocessing file ./test_data/8380...
# Preprocessing file ./test_data/8388...
# Preprocessing file ./test_data/8415...
# Preprocessing file ./test_data/8430...
# Preprocessing file ./test_data/8431...
# Preprocessing file ./test_data/8437...
# Preprocessing file ./test_data/8439...
# Preprocessing file ./test_data/8445...
# Preprocessing file ./test_data/8447...
# Preprocessing file ./test_data/8450...
# Preprocessing file ./test_data/8452...
# Preprocessing file ./test_data/8461...
# Preprocessing file ./test_data/8473...
# Preprocessing file ./test_data/8509...
# Preprocessing file ./test_data/8513...
# Preprocessing file ./test_data/8514...
# Preprocessing file ./test_data/8517...
# Preprocessing file ./test_data/8521...
# Preprocessing file ./test_data/8544...
# Preprocessing file ./test_data/8548...
# Preprocessing file ./test_data/8552...
# Preprocessing file ./test_data/8562...
# Preprocessing file ./test_data/8565...
# Preprocessing file ./test_data/8569...
# Preprocessing file ./test_data/8570...
# Preprocessing file ./test_data/8588...
# Preprocessing file ./test_data/8601...
# Preprocessing file ./test_data/8607...
# Preprocessing file ./test_data/8613...
# Preprocessing file ./test_data/8617...
# Preprocessing file ./test_data/8619...
# Preprocessing file ./test_data/8655...
# Preprocessing file ./test_data/8665...
# Preprocessing file ./test_data/8676...
# Preprocessing file ./test_data/8696...
# Preprocessing file ./test_data/8703...
# Preprocessing file ./test_data/8729...
# Preprocessing file ./test_data/8731...
# Preprocessing file ./test_data/8733...
# Preprocessing file ./test_data/8740...
# Preprocessing file ./test_data/8746...
# Preprocessing file ./test_data/8764...
# Preprocessing file ./test_data/8766...
# Preprocessing file ./test_data/8768...
# Preprocessing file ./test_data/8770...
# Preprocessing file ./test_data/8772...
# Preprocessing file ./test_data/8777...
# Preprocessing file ./test_data/8782...
# Preprocessing file ./test_data/8786...
# Preprocessing file ./test_data/8830...
# Preprocessing file ./test_data/8838...
# Preprocessing file ./test_data/8846...
# Preprocessing file ./test_data/8847...
# Preprocessing file ./test_data/8853...
# Preprocessing file ./test_data/8854...
# Preprocessing file ./test_data/8856...
# Preprocessing file ./test_data/8867...
# Preprocessing file ./test_data/8869...
# Preprocessing file ./test_data/8894...
# Preprocessing file ./test_data/8895...
# Preprocessing file ./test_data/8901...
# Preprocessing file ./test_data/8906...
# Preprocessing file ./test_data/8915...
# Preprocessing file ./test_data/8916...
# Preprocessing file ./test_data/8919...
# Preprocessing file ./test_data/8935...
# Preprocessing file ./test_data/8948...
# Preprocessing file ./test_data/8953...
# Preprocessing file ./test_data/8959...
# Preprocessing file ./test_data/8963...
# Preprocessing file ./test_data/8977...
# Preprocessing file ./test_data/8978...
# Preprocessing file ./test_data/9003...
# Preprocessing file ./test_data/9005...
# Preprocessing file ./test_data/9032...
# Preprocessing file ./test_data/9042...
# Preprocessing file ./test_data/9072...
# Preprocessing file ./test_data/9100...
# Preprocessing file ./test_data/9105...
# Preprocessing file ./test_data/9114...
# Preprocessing file ./test_data/9119...
# Preprocessing file ./test_data/9122...
# Preprocessing file ./test_data/9125...
# Preprocessing file ./test_data/9126...
# Preprocessing file ./test_data/9143...
# Preprocessing file ./test_data/9147...
# Preprocessing file ./test_data/9171...
# Preprocessing file ./test_data/9194...
# Preprocessing file ./test_data/9208...
# Preprocessing file ./test_data/9229...
# Preprocessing file ./test_data/9231...
# Preprocessing file ./test_data/9235...
# Preprocessing file ./test_data/9259...
# Preprocessing file ./test_data/9260...
# Preprocessing file ./test_data/9315...
# Preprocessing file ./test_data/9323...
# Preprocessing file ./test_data/9365...
# Preprocessing file ./test_data/9367...
# Preprocessing file ./test_data/9369...
# Preprocessing file ./test_data/9379...
# Preprocessing file ./test_data/9400...
# Preprocessing file ./test_data/9420...
# Preprocessing file ./test_data/9424...
# Preprocessing file ./test_data/9445...
# Preprocessing file ./test_data/9448...
# Preprocessing file ./test_data/9459...
# Preprocessing file ./test_data/9460...
# Preprocessing file ./test_data/9482...
# Preprocessing file ./test_data/9484...
# Preprocessing file ./test_data/9486...
# Preprocessing file ./test_data/9488...
# Preprocessing file ./test_data/9491...
# Preprocessing file ./test_data/9512...
# Preprocessing file ./test_data/9517...
# Preprocessing file ./test_data/9524...
# Preprocessing file ./test_data/9556...
# Preprocessing file ./test_data/9560...
# Preprocessing file ./test_data/9563...
# Preprocessing file ./test_data/9568...
# Preprocessing file ./test_data/9571...
# Preprocessing file ./test_data/9586...
# Preprocessing file ./test_data/9591...
# Preprocessing file ./test_data/9597...
# Preprocessing file ./test_data/9600...
# Preprocessing file ./test_data/9601...
# Preprocessing file ./test_data/9605...
# Preprocessing file ./test_data/9630...
# Preprocessing file ./test_data/9634...
# Preprocessing file ./test_data/9642...
# Preprocessing file ./test_data/9652...
# Preprocessing file ./test_data/9669...
# Preprocessing file ./test_data/9677...
# Preprocessing file ./test_data/9685...
# Preprocessing file ./test_data/9692...
# Preprocessing file ./test_data/9704...
# Preprocessing file ./test_data/9723...
# Preprocessing file ./test_data/9729...
# Preprocessing file ./test_data/9735...
# Preprocessing file ./test_data/9739...
# Preprocessing file ./test_data/9740...
# Preprocessing file ./test_data/9760...
# Preprocessing file ./test_data/9798...
# Preprocessing file ./test_data/9803...
# Preprocessing file ./test_data/9813...
# Preprocessing file ./test_data/9820...
# Preprocessing file ./test_data/9823...
# Preprocessing file ./test_data/9827...
# Preprocessing file ./test_data/9831...
# Preprocessing file ./test_data/9854...
# Preprocessing file ./test_data/9856...
# Preprocessing file ./test_data/9860...
# Preprocessing file ./test_data/9864...
# Preprocessing file ./test_data/9874...
# Preprocessing file ./test_data/9881...
# Preprocessing file ./test_data/9894...
# Preprocessing file ./test_data/9897...
# Preprocessing file ./test_data/9905...
# Preprocessing file ./test_data/9915...
# Preprocessing file ./test_data/9916...
# Preprocessing file ./test_data/9925...
# Preprocessing file ./test_data/9926...
# Preprocessing file ./test_data/9932...
# Preprocessing file ./test_data/9939...
# Preprocessing file ./test_data/9940...
# Preprocessing file ./test_data/9952...
# Preprocessing file ./test_data/9959...
# Preprocessing file ./test_data/9965...
# Preprocessing file ./test_data/9973...
# Preprocessing file ./test_data/9974...
# Preprocessing file ./test_data/9986...
# Preprocessing file ./test_data/9993...
